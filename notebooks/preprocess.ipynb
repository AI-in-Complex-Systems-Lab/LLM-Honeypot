# %%
from datetime import datetime
import pandas as pd
import json
from datasets import load_dataset, Dataset, DatasetDict

# %%
dataset = load_dataset("hotal/linux_commands")
dataset
# Out:
# ...
# Generating train split: 100%|██████████| 481/481 [00:00<00:00, 108763.83 examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['system', 'command', 'response', '__index_level_0__'],
#         num_rows: 481
#     })
# })

# %%
df = pd.DataFrame(dataset['train'])
df
# Out:
#                                                 system          command  \
# 0    I want you to understand what every Linux term...            chgrp
# 1    I want you to understand what every Linux term...             more
# 2    I want you to understand what every Linux term...  git-hash-object
# 3    I want you to understand what every Linux term...               id
# 4    I want you to understand what every Linux term...               nl
# ..                                                 ...              ...
# 476  I want you to understand what every Linux term...            sleep
# 477  I want you to understand what every Linux term...          manpath
# 478  I want you to understand what every Linux term...               mv
# 479  I want you to understand what every Linux term...          whereis
# 480  I want you to understand what every Linux term...       git-daemon
#
#                                               response  __index_level_0__
# ...

# %%
for i, data in df.iterrows():
    df.loc[i, 'system'] = "You are a linux expert. You understand what every Linux terminal command does and you reply with the explanation when asked."

df = df.drop('__index_level_0__', axis=1)
df
# Out:
#                                                 system          command  \
# 0    You are a linux expert. You understand what ev...            chgrp
# 1    You are a linux expert. You understand what ev...             more
# 2    You are a linux expert. You understand what ev...  git-hash-object
# 3    You are a linux expert. You understand what ev...               id
# 4    You are a linux expert. You understand what ev...               nl
# ..                                                 ...              ...
# 476  You are a linux expert. You understand what ev...            sleep
# 477  You are a linux expert. You understand what ev...          manpath
# 478  You are a linux expert. You understand what ev...               mv
# 479  You are a linux expert. You understand what ev...          whereis
# 480  You are a linux expert. You understand what ev...       git-daemon
#
#                                               response
# ...

# %%
s = df.command.str.len().sort_values(ascending=True).index
df = df.reindex(s).reset_index(drop=True)
df
# Out:
#                                                 system               command  \
# 0    You are a linux expert. You understand what ev...                     w
# 1    You are a linux expert. You understand what ev...                    ar
# 2    You are a linux expert. You understand what ev...                    mv
# 3    You are a linux expert. You understand what ev...                    ps
# 4    You are a linux expert. You understand what ev...                    ld
# ..                                                 ...                   ...
# 476  You are a linux expert. You understand what ev...   git-cvsexportcommit
# 477  You are a linux expert. You understand what ev...   update-alternatives
# 478  You are a linux expert. You understand what ev...  git-credential-store
# 479  You are a linux expert. You understand what ev...  git-credential-cache
# 480  You are a linux expert. You understand what ev...  git-check-ref-format
#
# ...

# %%
from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('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')

# %%
dataset = Dataset.from_pandas(df)
dataset.push_to_hub("hotal/linux_commands")
# Out:
# ...
# Uploading the dataset shards: 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# CommitInfo(commit_url='https://huggingface.co/datasets/hotal/linux_commands/commit/96c38caacb53d0b586cb93731b94e3e0dad1fa10', commit_message='Upload dataset', commit_description='', oid='96c38caacb53d0b586cb93731b94e3e0dad1fa10', pr_url=None, pr_revision=None, pr_num=None)
